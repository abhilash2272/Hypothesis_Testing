# %%
import pandas as pd
import seaborn as sn
import matplotlib.pyplot as plt
df = sn.load_dataset('taxis')

# %%
df.shape
# Out:
# (6433, 14)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6433 entries, 0 to 6432
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   pickup           6433 non-null   datetime64[ns]
#  1   dropoff          6433 non-null   datetime64[ns]
#  2   passengers       6433 non-null   int64
#  3   distance         6433 non-null   float64
#  4   fare             6433 non-null   float64
#  5   tip              6433 non-null   float64
#  6   tolls            6433 non-null   float64
#  7   total            6433 non-null   float64
#  8   color            6433 non-null   object
#  9   payment          6389 non-null   object
#  10  pickup_zone      6407 non-null   object
#  11  dropoff_zone     6388 non-null   object
#  12  pickup_borough   6407 non-null   object
#  13  dropoff_borough  6388 non-null   object
# dtypes: datetime64[ns](2), float64(5), int64(1), object(6)
# memory usage: 703.7+ KB

# %%
df.describe()
# Out:
#                               pickup                        dropoff  \
# count                           6433                           6433
# mean   2019-03-16 08:31:28.514223616  2019-03-16 08:45:49.491217408
# min              2019-02-28 23:29:03            2019-02-28 23:32:35
# 25%              2019-03-08 15:50:34            2019-03-08 16:12:51
# 50%              2019-03-15 21:46:58            2019-03-15 22:06:44
# 75%              2019-03-23 17:41:38            2019-03-23 17:51:56
# max              2019-03-31 23:43:45            2019-04-01 00:13:58
# std                              NaN                            NaN
#
#         passengers     distance         fare         tip        tolls  \
# count  6433.000000  6433.000000  6433.000000  6433.00000  6433.000000
# mean      1.539251     3.024617    13.091073     1.97922     0.325273
# min       0.000000     0.000000     1.000000     0.00000     0.000000
# 25%       1.000000     0.980000     6.500000     0.00000     0.000000
# 50%       1.000000     1.640000     9.500000     1.70000     0.000000
# 75%       2.000000     3.210000    15.000000     2.80000     0.000000
# max       6.000000    36.700000   150.000000    33.20000    24.020000
# std       1.203768     3.827867    11.551804     2.44856     1.415267
#
#              total
# count  6433.000000
# mean     18.517794
# min       1.300000
# 25%      10.800000
# 50%      14.160000
# 75%      20.300000
# max     174.820000
# std      13.815570

# %%
df.describe(include='object')
# Out:
#          color      payment     pickup_zone           dropoff_zone  \
# count     6433         6389            6407                   6388
# unique       2            2             194                    203
# top     yellow  credit card  Midtown Center  Upper East Side North
# freq      5451         4577             230                    245
#
#        pickup_borough dropoff_borough
# count            6407            6388
# unique              4               5
# top         Manhattan       Manhattan
# freq             5268            5206

# %%
df.isna().sum()
# Out:
# pickup              0
# dropoff             0
# passengers          0
# distance            0
# fare                0
# tip                 0
# tolls               0
# total               0
# color               0
# payment            44
# pickup_zone        26
# dropoff_zone       45
# pickup_borough     26
# dropoff_borough    45
# dtype: int64

# %%
df.isna().sum()/df.shape[0]*100
# Out:
# pickup             0.000000
# dropoff            0.000000
# passengers         0.000000
# distance           0.000000
# fare               0.000000
# tip                0.000000
# tolls              0.000000
# total              0.000000
# color              0.000000
# payment            0.683973
# pickup_zone        0.404166
# dropoff_zone       0.699518
# pickup_borough     0.404166
# dropoff_borough    0.699518
# dtype: float64

# %%
((df.shape[0]-df.dropna().shape[0])/df.shape[0])*100
# Out:
# 1.4301259132597544

# %%
df=df.dropna()

# %%
df.reset_index(drop='true')
# Out:
#                   pickup             dropoff  passengers  distance  fare  \
# 0    2019-03-23 20:21:09 2019-03-23 20:27:24           1      1.60   7.0
# 1    2019-03-04 16:11:55 2019-03-04 16:19:00           1      0.79   5.0
# 2    2019-03-27 17:53:01 2019-03-27 18:00:25           1      1.37   7.5
# 3    2019-03-10 01:23:59 2019-03-10 01:49:51           1      7.70  27.0
# 4    2019-03-30 13:27:42 2019-03-30 13:37:14           3      2.16   9.0
# ...                  ...                 ...         ...       ...   ...
# 6336 2019-03-31 09:51:53 2019-03-31 09:55:27           1      0.75   4.5
# 6337 2019-03-31 17:38:00 2019-03-31 18:34:23           1     18.74  58.0
# 6338 2019-03-23 22:55:18 2019-03-23 23:14:25           1      4.14  16.0
# 6339 2019-03-04 10:09:25 2019-03-04 10:14:29           1      1.12   6.0
# 6340 2019-03-13 19:31:22 2019-03-13 19:48:02           1      3.85  15.0
#
#        tip  tolls  total   color      payment            pickup_zone  \
# 0     2.15    0.0  12.95  yellow  credit card        Lenox Hill West
# 1     0.00    0.0   9.30  yellow         cash  Upper West Side South
# 2     2.36    0.0  14.16  yellow  credit card          Alphabet City
# 3     6.15    0.0  36.95  yellow  credit card              Hudson Sq
# 4     1.10    0.0  13.40  yellow  credit card           Midtown East
# ...    ...    ...    ...     ...          ...                    ...
# 6336  1.06    0.0   6.36   green  credit card      East Harlem North
# 6337  0.00    0.0  58.80   green  credit card                Jamaica
# 6338  0.00    0.0  17.30   green         cash    Crown Heights North
# 6339  0.00    0.0   6.80   green  credit card          East New York
# 6340  3.36    0.0  20.16   green  credit card            Boerum Hill
#
#                           dropoff_zone pickup_borough dropoff_borough
# 0                  UN/Turtle Bay South      Manhattan       Manhattan
# 1                Upper West Side South      Manhattan       Manhattan
# 2                         West Village      Manhattan       Manhattan
# 3                       Yorkville West      Manhattan       Manhattan
# 4                       Yorkville West      Manhattan       Manhattan
# ...                                ...            ...             ...
# 6336              Central Harlem North      Manhattan       Manhattan
# 6337  East Concourse/Concourse Village         Queens           Bronx
# 6338                    Bushwick North       Brooklyn        Brooklyn
# 6339      East Flatbush/Remsen Village       Brooklyn        Brooklyn
# 6340                   Windsor Terrace       Brooklyn        Brooklyn
#
# [6341 rows x 14 columns]

# %%
df.color.value_counts()
# Out:
# color
# yellow    5373
# green      968
# Name: count, dtype: int64

# %%
sn.barplot(x=df.color,y=df.tip,estimator='mean')
# Out:
# <Axes: xlabel='color', ylabel='tip'>

# %%
sn.barplot(x=df.color,y=df.tip,estimator='std')
# Out:
# <Axes: xlabel='color', ylabel='tip'>

# %%
sn.histplot(x=df.tip,hue=df.color,kde=True)
# Out:
# <Axes: xlabel='tip', ylabel='Count'>

# %%
#In barplot i have observed that yellow color taxis got more tip than green taxi.It means color effects on tip.
#In histogram i have observed that most people are likely to give small tips like 0 to 5.

# %%
#Hypothesis
#H0: distribution of tip of yellow taxi = distribution of tip of green taxi
#H1: distribution of tip of yellow taxi != distribution of tip of green taxi

# %%
# Independent T-Test
from scipy import stats
yellow_tip = df['tip'][df['color']=='yellow']
green_tip = df['tip'][df['color']=='green']

t_stat, p_val = stats.ttest_ind(yellow_tip, green_tip)
print("Independent T-Test statistic:", t_stat)
print("P-value:", p_val)

if p_val < 0.05:
    print("Reject null hypothesis: Tip differs by Color of taxi")
else:
    print("Fail to reject null hypothesis: No significant tip difference by Color of taxi")
# Out:
# Independent T-Test statistic: 17.05932566128597
# P-value: 7.791088119489451e-64
# Reject null hypothesis: Tip differs by Color of taxi

# %%
#Payment column

# %%
sn.barplot(x=df.payment,y=df.tip, estimator='mean')
# Out:
# <Axes: xlabel='payment', ylabel='tip'>

# %%
sn.histplot(x=df.tip,hue=df.payment,kde=True)
# Out:
# <Axes: xlabel='tip', ylabel='Count'>

# %%
df.payment.value_counts()
# Out:
# payment
# credit card    4546
# cash           1795
# Name: count, dtype: int64

# %%
from scipy import stats

cash_tip = df['tip'][df['payment'] == 'cash']
credit_card_tip = df['tip'][df['payment'] == 'credit card']

t_stat, p_val = stats.ttest_ind(cash_tip, credit_card_tip)

print(f"Independent T-Test statistic: {t_stat}")
print(f"P-value: {p_val}")

if p_val < 0.05:
    print("\nReject null hypothesis: There is a significant tip difference by payment method.")
else:
    print("\nFail to reject null hypothesis: No significant tip difference by payment method.")
# Out:
# Independent T-Test statistic: -49.09538452722153
# P-value: 0.0
#
# Reject null hypothesis: There is a significant tip difference by payment method.

# %%
df['pickup_borough'].value_counts()
# Out:
# pickup_borough
# Manhattan    5226
# Queens        638
# Brooklyn      378
# Bronx          99
# Name: count, dtype: int64

# %%
sn.countplot(x=df['pickup_borough'],palette='Set1')
# Out:
# /tmp/ipython-input-45422285.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sn.countplot(x=df['pickup_borough'],palette='Set1')
# <Axes: xlabel='pickup_borough', ylabel='count'>

# %%
sn.barplot(x=df.pickup_borough,y=df.tip,estimator='mean',palette='Set3')
# Out:
# /tmp/ipython-input-2732222786.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sn.barplot(x=df.pickup_borough,y=df.tip,estimator='mean',palette='Set3')
# <Axes: xlabel='pickup_borough', ylabel='tip'>

# %%
sn.histplot(x=df.tip, hue=df.pickup_borough, kde=True, bins=20, palette='Set3')
# Out:
# <Axes: xlabel='tip', ylabel='Count'>

# %%
#Hypothesis
#H0: All categories has same distribution of tip.
#H1: Atleast one category has different distribution of tip.

# %%
manhattan_tip=df['tip'][df['pickup_borough']=='Manhattan']
queens_tip=df['tip'][df['pickup_borough']=='Queens']
brooklyn_tip=df['tip'][df['pickup_borough']=='Brooklyn']
bronx_tip=df['tip'][df['pickup_borough']=='Bronx']

# %%
# ANOVA Test
from scipy import stats
f_stat, p_val = stats.f_oneway(manhattan_tip,queens_tip,brooklyn_tip,bronx_tip)
print("ANOVA F-statistic:", f_stat)
print("P-value:", p_val)

if p_val < 0.05:
    print("Reject null hypothesis: All categories has same distribution of tip. ")
else:
    print("Fail to reject null hypothesis: Atleast one category has different distribution of tip.")
# Out:
# ANOVA F-statistic: 91.57933831850573
# P-value: 5.155109332422435e-58
# Reject null hypothesis: All categories has same distribution of tip.

# %%
from statsmodels.stats.multicomp import pairwise_tukeyhsd
df['pickup_borough'] = df['pickup_borough'].astype(str).astype('category')
tukey_result = pairwise_tukeyhsd(endog=df.tip, groups=df.pickup_borough, alpha=0.05)
print(tukey_result)
# Out:
#   Multiple Comparison of Means - Tukey HSD, FWER=0.05
# =======================================================
#   group1    group2  meandiff p-adj lower  upper  reject
# -------------------------------------------------------
#     Bronx  Brooklyn   0.8305 0.008 0.1595 1.5015   True
#     Bronx Manhattan    1.797   0.0  1.194    2.4   True
#     Bronx    Queens   2.9179   0.0 2.2759 3.5599   True
#  Brooklyn Manhattan   0.9665   0.0 0.6499  1.283   True
#  Brooklyn    Queens   2.0873   0.0 1.7016 2.4731   True
# Manhattan    Queens   1.1209   0.0 0.8716 1.3701   True
# -------------------------------------------------------

# %%
df['dropoff_borough'].value_counts()
# Out:
# dropoff_borough
# Manhattan        5172
# Queens            534
# Brooklyn          497
# Bronx             136
# Staten Island       2
# Name: count, dtype: int64

# %%
sn.countplot(x=df['dropoff_borough'],palette='Set1')
# Out:
# /tmp/ipython-input-2719843853.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sn.countplot(x=df['dropoff_borough'],palette='Set1')
# <Axes: xlabel='dropoff_borough', ylabel='count'>

# %%
sn.barplot(x=df.dropoff_borough,y=df.tip,estimator='mean',palette='Set3')
# Out:
# /tmp/ipython-input-368125920.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sn.barplot(x=df.dropoff_borough,y=df.tip,estimator='mean',palette='Set3')
# <Axes: xlabel='dropoff_borough', ylabel='tip'>

# %%
sn.histplot(x=df.tip, hue=df.dropoff_borough, kde=True, bins=20, palette='Set1')
# Out:
# <Axes: xlabel='tip', ylabel='Count'>

# %%
# Hypothesis
# H0: Mean tip amount is the same across all drop-off boroughs
# H1: At least one borough has a different mean tip amount

# %%
manhattan_tip=df['tip'][df['dropoff_borough']=='Manhattan']
queens_tip=df['tip'][df['dropoff_borough']=='Queens']
brooklyn_tip=df['tip'][df['dropoff_borough']=='Brooklyn']
bronx_tip=df['tip'][df['dropoff_borough']=='Bronx']
staten_island_tip=df['tip'][df['dropoff_borough']=='Staten Island']

# %%
# ANOVA Test
f_stat, p_val = stats.f_oneway(manhattan_tip,queens_tip,brooklyn_tip,bronx_tip,staten_island_tip)
print("ANOVA F-statistic:", f_stat)
print("P-value:", p_val)

if p_val < 0.05:
    print("Reject null hypothesis: All categories has same distribution of tip. ")
else:
    print("Fail to reject null hypothesis: Atleast one category has different distribution of tip.")
# Out:
# ANOVA F-statistic: 31.424177966968298
# P-value: 5.87859571331583e-26
# Reject null hypothesis: All categories has same distribution of tip.

# %%
from statsmodels.stats.multicomp import pairwise_tukeyhsd
df['dropoff_borough'] = df['dropoff_borough'].astype(str).astype('category')
tukey_result = pairwise_tukeyhsd(endog=df.tip, groups=df.dropoff_borough, alpha=0.05)
print(tukey_result)
# Out:
#      Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ==============================================================
#   group1      group2    meandiff p-adj   lower   upper  reject
# --------------------------------------------------------------
#     Bronx      Brooklyn   1.3869    0.0  0.7691  2.0046   True
#     Bronx     Manhattan   1.4296    0.0  0.8751  1.9842   True
#     Bronx        Queens   1.8873    0.0  1.2742  2.5005   True
#     Bronx Staten Island  13.6303    0.0  9.0833 18.1773   True
#  Brooklyn     Manhattan   0.0427 0.9952 -0.2571  0.3425  False
#  Brooklyn        Queens   0.5004 0.0055  0.1026  0.8983   True
#  Brooklyn Staten Island  12.2434    0.0  7.7204 16.7664   True
# Manhattan        Queens   0.4577 0.0002  0.1675  0.7479   True
# Manhattan Staten Island  12.2007    0.0  7.6859 16.7154   True
#    Queens Staten Island   11.743    0.0  7.2206 16.2653   True
# --------------------------------------------------------------

# %%
df['pickup_zone'].value_counts()
# Out:
# pickup_zone
# Midtown Center                  227
# Penn Station/Madison Sq West    209
# Clinton East                    208
# Upper East Side South           208
# Midtown East                    196
#                                ...
# Ozone Park                        1
# Glendale                          1
# Woodlawn/Wakefield                1
# West Farms/Bronx River            1
# Hillcrest/Pomonok                 1
# Name: count, Length: 194, dtype: int64

# %%
sn.countplot(x=df['pickup_zone'])
# Out:
# <Axes: xlabel='pickup_zone', ylabel='count'>

# %%
# ANOVA Test
categories = [group['tip'].values for name, group in df.groupby('pickup_zone')]
f_stat, p_val = stats.f_oneway(*categories)
print("ANOVA F-statistic:", f_stat)
print("P-value:", p_val)

if p_val < 0.05:
    print("Reject null hypothesis: Spending Score differs by Region")
else:
    print("Fail to reject null hypothesis: No significant difference by Region")
# Out:
# ANOVA F-statistic: 7.563376210961916
# P-value: 7.892434822136223e-169
# Reject null hypothesis: Spending Score differs by Region

# %%
sn.histplot(df['tip'],kde=True)
# Out:
# <Axes: xlabel='tip', ylabel='Count'>

# %%
sn.histplot(df['passengers'],kde=True)
# Out:
# <Axes: xlabel='passengers', ylabel='Count'>

# %%
sn.scatterplot(y=df.tip,x=df.passengers)
# Out:
# <Axes: xlabel='passengers', ylabel='tip'>

# %%
# H0: correlation is zero
# H1: there is significant correlation(not zero)
r,p_val=stats.spearmanr(df['tip'],df['passengers'])
print("Correlation:",r)
print("P-value:",p_val)
alpha=0.05
if p_val<alpha:
    print("Reject null hypothesis")
else:
    print("Fail to reject null hypothesis")
# Out:
# Correlation: 0.027509812818779178
# P-value: 0.028480753176042872
# Reject null hypothesis

# %%
sn.histplot(df['fare'],kde=True)
# Out:
# <Axes: xlabel='fare', ylabel='Count'>

# %%
sn.scatterplot(y=df.tip,x=df.fare)
# Out:
# <Axes: xlabel='fare', ylabel='tip'>

# %%
# H0: correlation is zero
# H1: there is significant correlation(not zero)
r,p_val=stats.spearmanr(df['tip'],df['fare'])
print("Correlation:",r)
print("P-value:",p_val)
alpha=0.05
if p_val<alpha:
    print("Reject null hypothesis")
else:
    print("Fail to reject null hypothesis")
# Out:
# Correlation: 0.310254279563729
# P-value: 1.5556730728881364e-141
# Reject null hypothesis

# %%
sn.heatmap(df.select_dtypes(include='number').corr(),annot=True)
# Out:
# <Axes: >

# %%
sn.histplot(df['distance'],kde=True)
# Out:
# <Axes: xlabel='distance', ylabel='Count'>

# %%
sn.scatterplot(y=df.tip,x=df.distance)
# Out:
# <Axes: xlabel='distance', ylabel='tip'>

# %%
# H0: correlation is zero
# H1: there is significant correlation(not zero)
r,p_val=stats.spearmanr(df['tip'],df['distance'])
print("Correlation:",r)
print("P-value:",p_val)
alpha=0.05
if p_val<alpha:
    print("Reject null hypothesis")
else:
    print("Fail to reject null hypothesis")
# Out:
# Correlation: 0.29265085410043695
# P-value: 1.9411181331374707e-125
# Reject null hypothesis

# %%
sn.histplot(df['tolls'],kde=True)
# Out:
# <Axes: xlabel='tolls', ylabel='Count'>

# %%
sn.scatterplot(y=df.tip,x=df.tolls)
# Out:
# <Axes: xlabel='tolls', ylabel='tip'>

# %%
# H0: correlation is zero
# H1: there is significant correlation(not zero)
r,p_val=stats.spearmanr(df['tip'],df['tolls'])
print("Correlation:",r)
print("P-value:",p_val)
alpha=0.05
if p_val<alpha:
    print("Reject null hypothesis")
else:
    print("Fail to reject null hypothesis")
# Out:
# Correlation: 0.175380002891528
# P-value: 5.643276180955435e-45
# Reject null hypothesis

# %%
sn.histplot(df['total'],kde=True)
# Out:
# <Axes: xlabel='total', ylabel='Count'>

# %%
sn.scatterplot(y=df.tip,x=df.total)
# Out:
# <Axes: xlabel='total', ylabel='tip'>

# %%
# H0: correlation is zero
# H1: there is significant correlation(not zero)
r,p_val=stats.spearmanr(df['tip'],df['total'])
print("Correlation:",r)
print("P-value:",p_val)
alpha=0.05
if p_val<alpha:
    print("Reject null hypothesis")
else:
    print("Fail to reject null hypothesis")
# Out:
# Correlation: 0.5028299699182296
# P-value: 0.0
# Reject null hypothesis

# %%
# analyses with datetime columns

# %%
df['pickup']
# Out:
# 0      2019-03-23 20:21:09
# 1      2019-03-04 16:11:55
# 2      2019-03-27 17:53:01
# 3      2019-03-10 01:23:59
# 4      2019-03-30 13:27:42
#                ...
# 6428   2019-03-31 09:51:53
# 6429   2019-03-31 17:38:00
# 6430   2019-03-23 22:55:18
# 6431   2019-03-04 10:09:25
# 6432   2019-03-13 19:31:22
# Name: pickup, Length: 6341, dtype: datetime64[ns]

# %%
df['pickup'].dt.time
# Out:
# 0       20:21:09
# 1       16:11:55
# 2       17:53:01
# 3       01:23:59
# 4       13:27:42
#           ...
# 6428    09:51:53
# 6429    17:38:00
# 6430    22:55:18
# 6431    10:09:25
# 6432    19:31:22
# Name: pickup, Length: 6341, dtype: object

# %%
df['pickup'].dt.month
# Out:
# 0       3
# 1       3
# 2       3
# 3       3
# 4       3
#        ..
# 6428    3
# 6429    3
# 6430    3
# 6431    3
# 6432    3
# Name: pickup, Length: 6341, dtype: int32

# %%
df['pickup'].dt.day_name()
# Out:
# 0        Saturday
# 1          Monday
# 2       Wednesday
# 3          Sunday
# 4        Saturday
#           ...
# 6428       Sunday
# 6429       Sunday
# 6430     Saturday
# 6431       Monday
# 6432    Wednesday
# Name: pickup, Length: 6341, dtype: object

# %%
df['pickup_month']=df['pickup'].dt.month_name()

# %%
df['pickup_year']=df['pickup'].dt.year

# %%
df['pickup_dayname']=df['pickup'].dt.day_name()

# %%
df['pickup_day']=df['pickup'].dt.day

# %%
df['pickup_hour']=df['pickup'].dt.hour

# %%
df.head(3)
# Out:
#                pickup             dropoff  passengers  distance  fare   tip  \
# 0 2019-03-23 20:21:09 2019-03-23 20:27:24           1      1.60   7.0  2.15
# 1 2019-03-04 16:11:55 2019-03-04 16:19:00           1      0.79   5.0  0.00
# 2 2019-03-27 17:53:01 2019-03-27 18:00:25           1      1.37   7.5  2.36
#
#    tolls  total   color      payment            pickup_zone  \
# 0    0.0  12.95  yellow  credit card        Lenox Hill West
# 1    0.0   9.30  yellow         cash  Upper West Side South
# 2    0.0  14.16  yellow  credit card          Alphabet City
#
#             dropoff_zone pickup_borough dropoff_borough pickup_month  \
# 0    UN/Turtle Bay South      Manhattan       Manhattan        March
# 1  Upper West Side South      Manhattan       Manhattan        March
# 2           West Village      Manhattan       Manhattan        March
#
#    pickup_day  pickup_year pickup_dayname  pickup_hour
# 0          23         2019       Saturday           20
# 1           4         2019         Monday           16
# 2          27         2019      Wednesday           17

# %%
df['pickup_month'].value_counts()
# Out:
# pickup_month
# March       6340
# February       1
# Name: count, dtype: int64

# %%
df['pickup_month'].kurtosis()
# Out:
# np.float64(6341.000000000005)

# %%
sn.histplot(x=df.tip,hue=df.pickup_month,kde=True)
# Out:
# <Axes: xlabel='tip', ylabel='Count'>

# %%
sn.barplot(x=df.pickup_month,y=df.tip,estimator='mean')
# Out:
# <Axes: xlabel='pickup_month', ylabel='tip'>

# %%
#Hypothesis
#H0: distribution of tip of march month = distribution of tip of february
#H1: distribution of tip of march month != distribution of tip of february
# Independent T-Test
from scipy import stats
march_tip = df['tip'][df['pickup_month']=='March']
february_tip = df['tip'][df['pickup_month']=='February']

t_stat, p_val = stats.ttest_ind(march_tip, february_tip)
print("Independent T-Test statistic:", t_stat)
print("P-value:", p_val)

if p_val < 0.05:
    print("Reject null hypothesis: Tip differs in months")
else:
    print("Fail to reject null hypothesis: No significant tip difference in any month")
# Out:
# Independent T-Test statistic: 0.8352658713084974
# P-value: 0.4035995080184128
# Fail to reject null hypothesis: No significant tip difference in any month

# %%
sn.histplot(x=df.tip,hue=df.pickup_dayname,kde=True)
# Out:
# <Axes: xlabel='tip', ylabel='Count'>

# %%
sn.barplot(x=df.pickup_dayname,y=df.tip,estimator='mean')
# Out:
# <Axes: xlabel='pickup_dayname', ylabel='tip'>

# %%
sn.countplot(x=df['pickup_dayname'])
# ANOVA Test
categories = [group['tip'].values for name, group in df.groupby('pickup_dayname')]
f_stat, p_val = stats.f_oneway(*categories)
print("ANOVA F-statistic:", f_stat)
print("P-value:", p_val)

if p_val < 0.05:
    print("Reject null hypothesis: Spending Score differs by Region")
else:
    print("Fail to reject null hypothesis: No significant difference by Region")
# Out:
# ANOVA F-statistic: 1.6689152148182256
# P-value: 0.1242843162257308
# Fail to reject null hypothesis: No significant difference by Region

# %%
df['dropoff_month']=df['dropoff'].dt.month_name()
df['dropoff_year']=df['dropoff'].dt.year
df['dropoff_day']=df['dropoff'].dt.day
df['dropoff_dayname']=df['dropoff'].dt.day_name()
df['dropoff_hour']=df['dropoff'].dt.hour

# %%
df.head(1)
# Out:
#                pickup             dropoff  passengers  distance  fare   tip  \
# 0 2019-03-23 20:21:09 2019-03-23 20:27:24           1       1.6   7.0  2.15
#
#    tolls  total   color      payment  ... pickup_month pickup_day pickup_year  \
# 0    0.0  12.95  yellow  credit card  ...        March         23        2019
#
#   pickup_dayname pickup_hour  dropoff_month  dropoff_year dropoff_day  \
# 0       Saturday          20          March          2019          23
#
#    dropoff_dayname dropoff_hour
# 0         Saturday           20
#
# [1 rows x 24 columns]

# %%
sn.countplot(x=df['dropoff_dayname'])
# ANOVA Test
categories = [group['tip'].values for name, group in df.groupby('dropoff_dayname')]
f_stat, p_val = stats.f_oneway(*categories)
print("ANOVA F-statistic:", f_stat)
print("P-value:", p_val)

if p_val < 0.05:
    print("Reject null hypothesis: Spending Score differs in days")
else:
    print("Fail to reject null hypothesis: No significant difference in days")
# Out:
# ANOVA F-statistic: 1.6190096694735556
# P-value: 0.13742247930087778
# Fail to reject null hypothesis: No significant difference in days

# %%
df['dropoff_month'].value_counts()
# Out:
# dropoff_month
# March       6339
# April          1
# February       1
# Name: count, dtype: int64

# %%
sn.countplot(x=df['dropoff_month'])
# ANOVA Test
categories = [group['tip'].values for name, group in df.groupby('dropoff_month')]
f_stat, p_val = stats.f_oneway(*categories)
print("ANOVA F-statistic:", f_stat)
print("P-value:", p_val)

if p_val < 0.05:
    print("Reject null hypothesis: Spending Score differs in days")
else:
    print("Fail to reject null hypothesis: No significant difference in days")
# Out:
# ANOVA F-statistic: 0.6977458764114045
# P-value: 0.4977441577891454
# Fail to reject null hypothesis: No significant difference in days

# %%
df['pickup_year'].unique()
# Out:
# array([2019], dtype=int32)

# %%
df['dropoff_year'].unique()
# Out:
# array([2019], dtype=int32)

# %%
df['dropoff_day'].unique()
# Out:
# array([23,  4, 27, 10, 30, 11, 26,  8, 16, 20, 18, 19, 15, 25, 21, 28, 24,
#         3,  6,  1, 17, 22,  7, 14, 13,  5,  9,  2, 31, 12, 29],
#       dtype=int32)

# %%
df['dropoff_day'].skew()
# Out:
# np.float64(0.050247468887452844)

# %%
df['dropoff_day'].kurtosis()
# Out:
# np.float64(-1.1763875279781784)

# %%
# H0: correlation is zero
# H1: there is significant correlation(not zero)
r,p_val=stats.spearmanr(df['tip'],df['dropoff_day'])
print("Correlation:",r)
print("P-value:",p_val)
alpha=0.05
if p_val<alpha:
    print("Reject null hypothesis")
else:
    print("Fail to reject null hypothesis")
# Out:
# Correlation: 0.010829999394669469
# P-value: 0.38854863611464274
# Fail to reject null hypothesis

# %%
df['pickup_hour'].unique()
# Out:
# array([20, 16, 17,  1, 13, 10, 21, 11, 19,  7, 12,  6, 22,  3, 23,  9,  8,
#         2, 15, 18,  5, 14,  0,  4], dtype=int32)

# %%
df['pickup_hour'].skew()
# Out:
# np.float64(-0.48079237828578225)

# %%
# H0: correlation is zero
# H1: there is significant correlation(not zero)
r,p_val=stats.pearsonr(df['tip'],df['pickup_hour'])
print("Correlation:",r)
print("P-value:",p_val)
alpha=0.05
if p_val<alpha:
    print("Reject null hypothesis")
else:
    print("Fail to reject null hypothesis")
# Out:
# Correlation: 0.026615033651540543
# P-value: 0.0340631589058849
# Reject null hypothesis

# %%
# H0: correlation is zero
# H1: there is significant correlation(not zero)
r,p_val=stats.pearsonr(df['tip'],df['dropoff_hour'])
print("Correlation:",r)
print("P-value:",p_val)
alpha=0.05
if p_val<alpha:
    print("Reject null hypothesis")
else:
    print("Fail to reject null hypothesis")
# Out:
# Correlation: 0.032402365560439024
# P-value: 0.00986910678562921
# Reject null hypothesis

# %%
drop_list=['pickup_month','pickup_year','pickup_day','pickup','dropoff_month','dropoff_year','dropoff_day','dropoff']

# %%
df.drop(drop_list,axis=1,inplace=True)

# %%
df.head(1)
# Out:
#    passengers  distance  fare   tip  tolls  total   color      payment  \
# 0           1       1.6   7.0  2.15    0.0  12.95  yellow  credit card
#
#        pickup_zone         dropoff_zone pickup_borough dropoff_borough  \
# 0  Lenox Hill West  UN/Turtle Bay South      Manhattan       Manhattan
#
#   pickup_dayname  pickup_hour dropoff_dayname  dropoff_hour
# 0       Saturday           20        Saturday            20

# %%
from sklearn.preprocessing import LabelEncoder

# %%
lb=LabelEncoder()

# %%
cat=['color','payment','pickup_zone','dropoff_zone','pickup_borough','dropoff_borough','pickup_dayname','dropoff_dayname']
for i in cat:
  df[i]=lb.fit_transform(df[i])

# %%
df.head()
# Out:
#    passengers  distance  fare   tip  tolls  total  color  payment  \
# 0           1      1.60   7.0  2.15    0.0  12.95      1        1
# 1           1      0.79   5.0  0.00    0.0   9.30      1        0
# 2           1      1.37   7.5  2.36    0.0  14.16      1        1
# 3           1      7.70  27.0  6.15    0.0  36.95      1        1
# 4           3      2.16   9.0  1.10    0.0  13.40      1        1
#
#    pickup_zone  dropoff_zone  pickup_borough  dropoff_borough  pickup_dayname  \
# 0           99           176               2                2               2
# 1          174           182               2                2               1
# 2            1           190               2                2               6
# 3           86           202               2                2               3
# 4          116           202               2                2               2
#
#    pickup_hour  dropoff_dayname  dropoff_hour
# 0           20                2            20
# 1           16                1            16
# 2           17                6            18
# 3            1                3             1
# 4           13                2            13

# %%
con=['fare','tolls','total','distance']
from sklearn.preprocessing import StandardScaler
st=StandardScaler()
df[con]=st.fit_transform(df[con])

# %%
x=df.drop('tip',axis=1)
y=df.tip

# %%
x.shape
# Out:
# (6341, 15)

# %%
y.shape
# Out:
# (6341,)

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
from sklearn.linear_model import LinearRegression
model=LinearRegression()
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
model.coef_
# Out:
# array([-1.00960729e-02,  1.18137138e-01, -7.85417376e+00, -9.59105834e-01,
#         9.67146005e+00, -1.19693094e+00,  5.58103018e-01, -8.28840049e-04,
#        -1.54397768e-03,  2.18833421e-01, -7.94129774e-02,  7.39871519e-03,
#        -1.55568520e-02, -1.23446085e-02, -1.98943019e-03])

# %%
model.intercept_
# Out:
# np.float64(2.842106242324242)

# %%
y_train_pred=model.predict(x_train)
train_score=model.score(x_train,y_train)
train_score
# Out:
# 0.9240926502797042

# %%
y_test_pred=model.predict(x_test)
test_score=model.score(x_test,y_test)
test_score
# Out:
# 0.9250827837008955

# %%
from sklearn.metrics import root_mean_squared_error,mean_absolute_error,mean_squared_error,r2_score
print(root_mean_squared_error(y_train,y_train_pred))
print(mean_absolute_error(y_train,y_train_pred))
print(mean_squared_error(y_train,y_train_pred))
print(r2_score(y_train,y_train_pred))
# Out:
# 0.6551099087071314
# 0.43887771610767295
# 0.429168992486266
# 0.9240926502797042
